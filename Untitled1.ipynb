# %% [markdown]
# Hi all,
#
# The updated simulation results are as follow:
#
#
# |
# ratio over adversaries
#
# #adversarial
# 0    0.717171
# 2    0.504233
# 5    0.230671
# Name: ratio, dtype: float64
#
#
#
# The one-sided statistical tests indicate that more adversaries lead to lower probability of coordination (all p-values are less than 0.01).
#
#
#
# *********************************************************
# ratio over network
#
# network
# Barabasi-Albert       0.736425
# Erdos-Renyi-dense     0.545350
# Erdos-Renyi-sparse    0.170300
# Name: ratio, dtype: float64
#
#
# *********************************************************
# The one-sided statistical tests indicate that BA > ERD > ERS (all p-values are less than 0.01).
#
#
#
# *********************************************************
# ratio over visibleNodes
#
# #visibleNodes
# 0    0.496994
# 1    0.458667
# 2    0.469628
# 5    0.510811
# Name: ratio, dtype: float64
#
#
# *********************************************************
# The one-sided statistical tests indicate that:
#         0 visible node > 1 visible node (p-value < 0.01)
#         1 visible node < 2 visible nodes (p-value < 0.01)
#         2 visible nodes < 5 visible nodes (p-value < 0.01)
#         0 visible node < 5 visible nodes (p-value < 0.01)
#
#
#
#
# *********************************************************
# ratio over adversaries and visibleNodes
#
# #adversarial  #visibleNodes
# 0             0                0.739550
#               1                0.691200
#               2                0.700717
#               5                0.737217
# 2             0                0.517067
#               1                0.476650
#               2                0.488000
#               5                0.535217
# 5             0                0.234367
#               1                0.208150
#               2                0.220167
#               5                0.260000
# Name: ratio, dtype: float64
#
# *********************************************************
# The one-sided statistical tests indicate that:
#     1) 0 adversary:
#          0 visible node > 1 visible node (p-value<0.01)
#          1 visible node < 2 visible nodes (p-value<0.01)
#          2 visible node < 5 visible nodes (p-value<0.01)
#          0 visible node is not different from 5 visible nodes (p-value ~= 0.18)
#
#     2) 2 adversaries:
#          0 visible node > 1 visible node (p-value<0.01)
#          1 visible node < 2 visible nodes (p-value<0.01)
#          2 visible node < 5 visible nodes (p-value<0.01)
#          0 visible node < 5 visible nodes (p-value<0.01)
#
#     3) 5 adversaries:
#          0 visible node > 1 visible node (p-value<0.01)
#          1 visible node < 2 visible nodes (p-value<0.01)
#          2 visible node < 5 visible nodes (p-value<0.01)
#          0 visible node < 5 visible nodes (p-value<0.01)
#
#
#
#
#
# *********************************************************
# ratio over network and visibleNodes
#
# network             #visibleNodes
# Barabasi-Albert     0                0.745900
#                     1                0.714667
#                     2                0.721850
#                     5                0.763283
# Erdos-Renyi-dense   0                0.568833
#                     1                0.508833
#                     2                0.526967
#                     5                0.576767
# Erdos-Renyi-sparse  0                0.176250
#                     1                0.152500
#                     2                0.160067
#                     5                0.192383
# Name: ratio, dtype: float64
#
# *********************************************************
# The one-sided statistical tests indicate that:
#     1) BA:
#          0 visible node > 1 visible node (p-value<0.01)
#          1 visible node < 2 visible nodes (p-value<0.01)
#          2 visible node < 5 visible nodes (p-value<0.01)
#          0 visible node < 5 visible nodes (p-value<0.01)
#
#     2) ERD:
#          0 visible node > 1 visible node (p-value<0.01)
#          1 visible node < 2 visible nodes (p-value<0.01)
#          2 visible node < 5 visible nodes (p-value<0.01)
#          0 visible node < 5 visible nodes (p-value<0.01)
#
#     3) ERS:
#          0 visible node > 1 visible node (p-value<0.01)
#          1 visible node < 2 visible nodes (p-value<0.01)
#          2 visible node < 5 visible nodes (p-value<0.01)
#          0 visible node < 5 visible nodes (p-value<0.01)
